# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
data = fetch_california_housing()
X = data.data
y = data.target

# %%
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
print("Dataset shape:", X.shape)
print("Feature names:", data.feature_names)
# Out:
# Dataset shape: (20640, 8)
# Feature names: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "L1 (Lasso)": Lasso(alpha=0.1),
    "L2 (Ridge)": Ridge(alpha=1.0),
    "Elastic Net": ElasticNet(alpha=0.1, l1_ratio=0.5)
}

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{name} MSE: {mse:.4f}")
# Out:
# Linear Regression MSE: 0.5306
# L1 (Lasso) MSE: 0.6648
# L2 (Ridge) MSE: 0.5305
# Elastic Net MSE: 0.6200

# %%
coef_df = pd.DataFrame({
    name: model.fit(X_train, y_train).coef_
    for name, model in models.items()
}, index=data.feature_names)

print("\nModel Coefficients:")
print(coef_df)
# Out:
# Model Coefficients:
#             Linear Regression  L1 (Lasso)  L2 (Ridge)  Elastic Net
# MedInc               0.849222    0.708327    0.849152     0.710941
# HouseAge             0.122119    0.106594    0.122208     0.136722
# AveRooms            -0.299558   -0.000000   -0.299309    -0.000000
# AveBedrms            0.348410    0.000000    0.348103     0.000000
# Population          -0.000884   -0.000000   -0.000854     0.000000
# AveOccup            -0.041698   -0.000000   -0.041702    -0.000000
# Latitude            -0.893856   -0.010425   -0.893003    -0.178613
# Longitude           -0.868617   -0.000000   -0.867752    -0.137818

# %%
plt.figure(figsize=(10,6))
for name, model in models.items():
    model.fit(X_train, y_train)
    plt.plot(model.coef_, label=name)

plt.title("Effect of Regularization on California Housing Dataset")
plt.xlabel("Feature Index")
plt.ylabel("Coefficient Value")
plt.legend()
plt.show()

# %%
# !git fetch origin

# %%
# !git branch -r

# %%
# !git remote -v
# Out:
# origin	https://github.com/Kusum004/Adaptive-multi-modal-.git (fetch)
# origin	https://github.com/Kusum004/Adaptive-multi-modal-.git (push)

# %%
# !git clone https://github.com/Kusum004/SPR-2548532.git
# Out:
# fatal: destination path 'SPR-2548532' already exists and is not an empty directory.

# %%
cd SPR-2548532
# Out:
# c:\Users\S Kusum\Documents\Deep Learning\SPR-2548532

# %%
# !git remote -v
# Out:
# origin	https://github.com/Kusum004/SPR-2548532.git (fetch)
# origin	https://github.com/Kusum004/SPR-2548532.git (push)

# %%
# !git checkout -b lab3
# !git add .
# !git commit -m "Added Lab 3"
# !git push -u origin lab3
# Out:
# Switched to a new branch 'lab3'
# On branch lab3
# nothing to commit, working tree clean
# branch 'lab3' set up to track 'origin/lab3'.
# remote:
# remote: Create a pull request for 'lab3' on GitHub by visiting:
# remote:      https://github.com/Kusum004/SPR-2548532/pull/new/lab3
# remote:
# To https://github.com/Kusum004/SPR-2548532.git
#  * [new branch]      lab3 -> lab3

# %%
# !git remote -v
# Out:
# origin	https://github.com/Kusum004/SPR-2548532.git (fetch)
# origin	https://github.com/Kusum004/SPR-2548532.git (push)

# %%
# !git branch
# Out:
# * lab3
#   main

# %%
# !git status
# Out:
# On branch lab3
# Your branch is up to date with 'origin/lab3'.
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m "Added Lab 3 Code"
# Out:
# On branch lab3
# Your branch is up to date with 'origin/lab3'.
#
# nothing to commit, working tree clean

# %%
# !git push origin lab3
# Out:
# Everything up-to-date

# %%
# !git add lab3.ipynb
# !git commit -m "Added Lab 3 notebook"
# Out:
# fatal: pathspec 'lab3.ipynb' did not match any files
# On branch lab3
# Your branch is up to date with 'origin/lab3'.
#
# nothing to commit, working tree clean
